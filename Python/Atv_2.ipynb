# %% [markdown]
# # Gabriel Luna - 210060
# ## Com Constante

# %%
#Importando bibliotecas
import pandas as pd
import statsmodels.api as sm

# %%
#Lendo o arquivo
dados = pd.read_csv("bike-rental_day.csv", index_col=0)
print(dados)
# Out:
#              dteday  season  yr  mnth  holiday  weekday  workingday  \
# instant
# 1          1/1/2011       1   0     1        0        6           0
# 2          1/2/2011       1   0     1        0        0           0
# 3          1/3/2011       1   0     1        0        1           1
# 4          1/4/2011       1   0     1        0        2           1
# 5          1/5/2011       1   0     1        0        3           1
# ...             ...     ...  ..   ...      ...      ...         ...
# 727      12/27/2012       1   1    12        0        4           1
# 728      12/28/2012       1   1    12        0        5           1
# 729      12/29/2012       1   1    12        0        6           0
# 730      12/30/2012       1   1    12        0        0           0
# 731      12/31/2012       1   1    12        0        1           1
#
#          weathersit      temp     atemp       hum  windspeed  casual  \
# instant
# ...

# %%
dados.head()
# Out:
#            dteday  season  yr  mnth  holiday  weekday  workingday  weathersit  \
# instant
# 1        1/1/2011       1   0     1        0        6           0           2
# 2        1/2/2011       1   0     1        0        0           0           2
# 3        1/3/2011       1   0     1        0        1           1           1
# 4        1/4/2011       1   0     1        0        2           1           1
# 5        1/5/2011       1   0     1        0        3           1           1
#
#              temp     atemp       hum  windspeed  casual  registered   cnt
# instant
# 1        0.344167  0.363625  0.805833   0.160446     331         654   985
# 2        0.363478  0.353739  0.696087   0.248539     131         670   801
# 3        0.196364  0.189405  0.437273   0.248309     120        1229  1349
# 4        0.200000  0.212122  0.590435   0.160296     108        1454  1562
# 5        0.226957  0.229270  0.436957   0.186900      82        1518  1600

# %%
dados.columns
# Out:
# Index(['dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday', 'workingday',
#        'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'casual',
#        'registered', 'cnt'],
#       dtype='object')

# %%
#Removendo variáveis sem sentido e rodando a regressão
nomes = ['season', 'yr','mnth', 'holiday', 'weekday', 'workingday',
       'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'cnt']
dados2 = dados[nomes]
inputs = dados2.columns[0:]

# %%
#Testando a correlação
dados.describe()
# Out:
#            season          yr        mnth     holiday     weekday  workingday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     2.496580    0.500684    6.519836    0.028728    2.997264    0.683995
# std      1.110807    0.500342    3.451913    0.167155    2.004787    0.465233
# min      1.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 25%      2.000000    0.000000    4.000000    0.000000    1.000000    0.000000
# 50%      3.000000    1.000000    7.000000    0.000000    3.000000    1.000000
# 75%      3.000000    1.000000   10.000000    0.000000    5.000000    1.000000
# max      4.000000    1.000000   12.000000    1.000000    6.000000    1.000000
#
#        weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     1.395349    0.495385    0.474354    0.627894    0.190486
# std      0.544894    0.183051    0.162961    0.142429    0.077498
# ...

# %%
dados2.corr()['cnt'].abs().sort_values(ascending=False)[:].index
# Out:
# Index(['cnt', 'atemp', 'temp', 'yr', 'season', 'weathersit', 'mnth',
#        'windspeed', 'hum', 'holiday', 'weekday', 'workingday'],
#       dtype='object')

# %%
#atemp true
X = dados['atemp']
Y = dados['cnt']
X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.398
# Model:                            OLS   Adj. R-squared:                  0.397
# Method:                 Least Squares   F-statistic:                     482.5
# Date:                Wed, 29 Mar 2023   Prob (F-statistic):           1.85e-82
# Time:                        23:13:37   Log-Likelihood:                -6384.0
# No. Observations:                 731   AIC:                         1.277e+04
# Df Residuals:                     729   BIC:                         1.278e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        945.8240    171.291      5.522      0.000     609.541    1282.107
# ...

# %%
#temp false
variaveis = ['atemp', 'temp']
X = dados[variaveis]
Y = dados['cnt']
X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.398
# Model:                            OLS   Adj. R-squared:                  0.397
# Method:                 Least Squares   F-statistic:                     241.1
# Date:                Wed, 29 Mar 2023   Prob (F-statistic):           4.62e-81
# Time:                        23:13:38   Log-Likelihood:                -6383.9
# No. Observations:                 731   AIC:                         1.277e+04
# Df Residuals:                     728   BIC:                         1.279e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        981.0365    188.362      5.208      0.000     611.238    1350.835
# ...

# %%
#yr pede por um novo estudo
variaveis = ['atemp', 'yr']
X = dados[variaveis]
Y = dados['cnt']
X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.688
# Model:                            OLS   Adj. R-squared:                  0.687
# Method:                 Least Squares   F-statistic:                     802.2
# Date:                Wed, 29 Mar 2023   Prob (F-statistic):          8.49e-185
# Time:                        23:13:38   Log-Likelihood:                -6144.1
# No. Observations:                 731   AIC:                         1.229e+04
# Df Residuals:                     728   BIC:                         1.231e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         41.4915    128.256      0.324      0.746    -210.304     293.287
# ...

# %%
#season True
variaveis = ['atemp', 'yr','season']
X = dados[variaveis]
Y = dados['cnt']
X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.733
# Model:                            OLS   Adj. R-squared:                  0.732
# Method:                 Least Squares   F-statistic:                     664.9
# Date:                Wed, 29 Mar 2023   Prob (F-statistic):          7.41e-208
# Time:                        23:13:38   Log-Likelihood:                -6087.2
# No. Observations:                 731   AIC:                         1.218e+04
# Df Residuals:                     727   BIC:                         1.220e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -511.9045    128.833     -3.973      0.000    -764.833    -258.976
# ...

# %%
#weathersit true
variaveis = ['atemp', 'yr', 'season', 'weathersit']
X = dados[variaveis]
Y = dados['cnt']
X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.778
# Model:                            OLS   Adj. R-squared:                  0.777
# Method:                 Least Squares   F-statistic:                     637.4
# Date:                Wed, 29 Mar 2023   Prob (F-statistic):          8.41e-236
# Time:                        23:13:38   Log-Likelihood:                -6019.0
# No. Observations:                 731   AIC:                         1.205e+04
# Df Residuals:                     726   BIC:                         1.207e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        684.4355    152.973      4.474      0.000     384.113     984.758
# ...

# %%
#mnth true
variaveis = ['atemp', 'yr', 'season', 'weathersit', 'mnth']
X = dados[variaveis]
Y = dados['cnt']
X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.780
# Model:                            OLS   Adj. R-squared:                  0.779
# Method:                 Least Squares   F-statistic:                     514.3
# Date:                Wed, 29 Mar 2023   Prob (F-statistic):          1.34e-235
# Time:                        23:13:38   Log-Likelihood:                -6016.1
# No. Observations:                 731   AIC:                         1.204e+04
# Df Residuals:                     725   BIC:                         1.207e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        699.1305    152.607      4.581      0.000     399.526     998.735
# ...

# %%
#windspeed true
variaveis = ['atemp', 'yr', 'season', 'weathersit', 'mnth', 'windspeed']
X = dados[variaveis]
Y = dados['cnt']
X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.786
# Model:                            OLS   Adj. R-squared:                  0.784
# Method:                 Least Squares   F-statistic:                     443.5
# Date:                Wed, 29 Mar 2023   Prob (F-statistic):          1.35e-238
# Time:                        23:13:38   Log-Likelihood:                -6006.0
# No. Observations:                 731   AIC:                         1.203e+04
# Df Residuals:                     724   BIC:                         1.206e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1191.8063    185.866      6.412      0.000     826.906    1556.706
# ...

# %%
#hum true
variaveis = ['atemp', 'yr', 'season', 'weathersit', 'mnth', 'windspeed','hum']
X = dados[variaveis]
Y = dados['cnt']
X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.790
# Model:                            OLS   Adj. R-squared:                  0.788
# Method:                 Least Squares   F-statistic:                     389.1
# Date:                Wed, 29 Mar 2023   Prob (F-statistic):          2.62e-240
# Time:                        23:13:38   Log-Likelihood:                -5998.8
# No. Observations:                 731   AIC:                         1.201e+04
# Df Residuals:                     723   BIC:                         1.205e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1677.2591    224.690      7.465      0.000    1236.135    2118.383
# ...

# %%
#holiday true
variaveis = ['atemp', 'yr', 'season', 'weathersit', 'mnth', 'windspeed','hum', 'holiday']
X = dados[variaveis]
Y = dados['cnt']
X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.794
# Model:                            OLS   Adj. R-squared:                  0.791
# Method:                 Least Squares   F-statistic:                     347.1
# Date:                Wed, 29 Mar 2023   Prob (F-statistic):          1.48e-241
# Time:                        23:13:38   Log-Likelihood:                -5992.9
# No. Observations:                 731   AIC:                         1.200e+04
# Df Residuals:                     722   BIC:                         1.205e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1710.7620    223.227      7.664      0.000    1272.511    2149.013
# ...

# %%
#weekday true
variaveis = ['atemp', 'yr', 'season', 'weathersit', 'mnth', 'windspeed','hum', 'holiday', 'weekday']
X = dados[variaveis]
Y = dados['cnt']
X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.799
# Model:                            OLS   Adj. R-squared:                  0.796
# Method:                 Least Squares   F-statistic:                     318.2
# Date:                Wed, 29 Mar 2023   Prob (F-statistic):          2.87e-244
# Time:                        23:13:38   Log-Likelihood:                -5983.5
# No. Observations:                 731   AIC:                         1.199e+04
# Df Residuals:                     721   BIC:                         1.203e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1458.3767    228.137      6.393      0.000    1010.484    1906.269
# ...

# %%
#workingday false
variaveis = ['atemp', 'yr', 'season', 'weathersit', 'mnth', 'windspeed','hum', 'holiday', 'weekday', 'workingday']
X = dados[variaveis]
Y = dados['cnt']
X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.800
# Model:                            OLS   Adj. R-squared:                  0.797
# Method:                 Least Squares   F-statistic:                     287.4
# Date:                Wed, 29 Mar 2023   Prob (F-statistic):          1.27e-243
# Time:                        23:13:38   Log-Likelihood:                -5982.1
# No. Observations:                 731   AIC:                         1.199e+04
# Df Residuals:                     720   BIC:                         1.204e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1380.4615    232.452      5.939      0.000     924.096    1836.827
# ...

# %%
#Modelo final que melhor explica a correlação
variaveis = ['atemp', 'yr', 'season', 'weathersit', 'mnth', 'windspeed','hum', 'holiday', 'weekday']
X = dados[variaveis]
Y = dados['cnt']
X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.799
# Model:                            OLS   Adj. R-squared:                  0.796
# Method:                 Least Squares   F-statistic:                     318.2
# Date:                Wed, 29 Mar 2023   Prob (F-statistic):          2.87e-244
# Time:                        23:13:39   Log-Likelihood:                -5983.5
# No. Observations:                 731   AIC:                         1.199e+04
# Df Residuals:                     721   BIC:                         1.203e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1458.3767    228.137      6.393      0.000    1010.484    1906.269
# ...

# %% [markdown]
# ## CNT = atemp + yr + season + weathersit + mnth + windspeed + hum + holiday + weekday

# %% [markdown]
# Necessário estudo em separado sem utilização da constante.
# Foram removidas as variáveis "instant", "dteday", "hr", "casual" e "registered" por não fazerem sentido dentro da análise.

# %% [markdown]
# As variáveis "temp", "workingday" por alterarem o P valor acima de 5%

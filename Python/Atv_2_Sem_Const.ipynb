# %% [markdown]
# # Gabriel Luna - 210060
# ## Sem Constante

# %%
#Importando bibliotecas
import pandas as pd
import statsmodels.api as sm

# %%
#Lendo o arquivo
dados = pd.read_csv("bike-rental_day.csv", index_col=0)
print(dados)
# Out:
#              dteday  season  yr  mnth  holiday  weekday  workingday  \
# instant
# 1          1/1/2011       1   0     1        0        6           0
# 2          1/2/2011       1   0     1        0        0           0
# 3          1/3/2011       1   0     1        0        1           1
# 4          1/4/2011       1   0     1        0        2           1
# 5          1/5/2011       1   0     1        0        3           1
# ...             ...     ...  ..   ...      ...      ...         ...
# 727      12/27/2012       1   1    12        0        4           1
# 728      12/28/2012       1   1    12        0        5           1
# 729      12/29/2012       1   1    12        0        6           0
# 730      12/30/2012       1   1    12        0        0           0
# 731      12/31/2012       1   1    12        0        1           1
#
#          weathersit      temp     atemp       hum  windspeed  casual  \
# instant
# 1                 2  0.344167  0.363625  0.805833   0.160446     331
# 2                 2  0.363478  0.353739  0.696087   0.248539     131
# 3                 1  0.196364  0.189405  0.437273   0.248309     120
# 4                 1  0.200000  0.212122  0.590435   0.160296     108
# 5                 1  0.226957  0.229270  0.436957   0.186900      82
# ...             ...       ...       ...       ...        ...     ...
# 727               2  0.254167  0.226642  0.652917   0.350133     247
# 728               2  0.253333  0.255046  0.590000   0.155471     644
# 729               2  0.253333  0.242400  0.752917   0.124383     159
# 730               1  0.255833  0.231700  0.483333   0.350754     364
# 731               2  0.215833  0.223487  0.577500   0.154846     439
#
#          registered   cnt
# instant
# 1               654   985
# 2               670   801
# 3              1229  1349
# 4              1454  1562
# 5              1518  1600
# ...             ...   ...
# 727            1867  2114
# 728            2451  3095
# 729            1182  1341
# 730            1432  1796
# 731            2290  2729
#
# [731 rows x 15 columns]

# %%
dados.head()
# Out:
#            dteday  season  yr  mnth  holiday  weekday  workingday  weathersit  \
# instant
# 1        1/1/2011       1   0     1        0        6           0           2
# 2        1/2/2011       1   0     1        0        0           0           2
# 3        1/3/2011       1   0     1        0        1           1           1
# 4        1/4/2011       1   0     1        0        2           1           1
# 5        1/5/2011       1   0     1        0        3           1           1
#
#              temp     atemp       hum  windspeed  casual  registered   cnt
# instant
# 1        0.344167  0.363625  0.805833   0.160446     331         654   985
# 2        0.363478  0.353739  0.696087   0.248539     131         670   801
# 3        0.196364  0.189405  0.437273   0.248309     120        1229  1349
# 4        0.200000  0.212122  0.590435   0.160296     108        1454  1562
# 5        0.226957  0.229270  0.436957   0.186900      82        1518  1600

# %%
dados.columns
# Out:
# Index(['dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday', 'workingday',
#        'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'casual',
#        'registered', 'cnt'],
#       dtype='object')

# %%
#Removendo variáveis sem sentido e rodando a regressão
nomes = ['season', 'yr','mnth', 'holiday', 'weekday', 'workingday',
       'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'cnt']
dados2 = dados[nomes]
inputs = dados2.columns[0:]

# %%
#Testando a correlação
dados.describe()
# Out:
#            season          yr        mnth     holiday     weekday  workingday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     2.496580    0.500684    6.519836    0.028728    2.997264    0.683995
# std      1.110807    0.500342    3.451913    0.167155    2.004787    0.465233
# min      1.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 25%      2.000000    0.000000    4.000000    0.000000    1.000000    0.000000
# 50%      3.000000    1.000000    7.000000    0.000000    3.000000    1.000000
# 75%      3.000000    1.000000   10.000000    0.000000    5.000000    1.000000
# max      4.000000    1.000000   12.000000    1.000000    6.000000    1.000000
#
#        weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     1.395349    0.495385    0.474354    0.627894    0.190486
# std      0.544894    0.183051    0.162961    0.142429    0.077498
# min      1.000000    0.059130    0.079070    0.000000    0.022392
# 25%      1.000000    0.337083    0.337842    0.520000    0.134950
# 50%      1.000000    0.498333    0.486733    0.626667    0.180975
# 75%      2.000000    0.655417    0.608602    0.730209    0.233214
# max      3.000000    0.861667    0.840896    0.972500    0.507463
#
#             casual   registered          cnt
# count   731.000000   731.000000   731.000000
# mean    848.176471  3656.172367  4504.348837
# std     686.622488  1560.256377  1937.211452
# min       2.000000    20.000000    22.000000
# 25%     315.500000  2497.000000  3152.000000
# 50%     713.000000  3662.000000  4548.000000
# 75%    1096.000000  4776.500000  5956.000000
# max    3410.000000  6946.000000  8714.000000

# %%
dados2.corr()['cnt'].abs().sort_values(ascending=False)[:].index
# Out:
# Index(['cnt', 'atemp', 'temp', 'yr', 'season', 'weathersit', 'mnth',
#        'windspeed', 'hum', 'holiday', 'weekday', 'workingday'],
#       dtype='object')

# %%
#atemp true
X = dados['atemp']
Y = dados['cnt']
model = sm.OLS(Y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    cnt   R-squared (uncentered):                   0.902
# Model:                            OLS   Adj. R-squared (uncentered):              0.902
# Method:                 Least Squares   F-statistic:                              6738.
# Date:                Wed, 29 Mar 2023   Prob (F-statistic):                        0.00
# Time:                        23:13:40   Log-Likelihood:                         -6399.0
# No. Observations:                 731   AIC:                                  1.280e+04
# Df Residuals:                     730   BIC:                                  1.280e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# atemp       9285.5270    113.117     82.088      0.000    9063.453    9507.601
# ==============================================================================
# Omnibus:                        3.502   Durbin-Watson:                   0.475
# Prob(Omnibus):                  0.174   Jarque-Bera (JB):                2.840
# Skew:                           0.024   Prob(JB):                        0.242
# Kurtosis:                       2.698   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#temp false
variaveis = ['atemp', 'temp']
X = dados[variaveis]
Y = dados['cnt']
model = sm.OLS(Y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    cnt   R-squared (uncentered):                   0.903
# Model:                            OLS   Adj. R-squared (uncentered):              0.902
# Method:                 Least Squares   F-statistic:                              3382.
# Date:                Wed, 29 Mar 2023   Prob (F-statistic):                        0.00
# Time:                        23:13:40   Log-Likelihood:                         -6397.3
# No. Observations:                 731   AIC:                                  1.280e+04
# Df Residuals:                     729   BIC:                                  1.281e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# atemp       1.354e+04   2307.312      5.869      0.000    9012.052    1.81e+04
# temp       -4047.1532   2191.308     -1.847      0.065   -8349.181     254.875
# ==============================================================================
# Omnibus:                        0.992   Durbin-Watson:                   0.496
# Prob(Omnibus):                  0.609   Jarque-Bera (JB):                0.916
# Skew:                           0.085   Prob(JB):                        0.632
# Kurtosis:                       3.029   Cond. No.                         40.9
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#yr ?
variaveis = ['atemp', 'yr']
X = dados[variaveis]
Y = dados['cnt']
model = sm.OLS(Y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    cnt   R-squared (uncentered):                   0.951
# Model:                            OLS   Adj. R-squared (uncentered):              0.951
# Method:                 Least Squares   F-statistic:                              7125.
# Date:                Wed, 29 Mar 2023   Prob (F-statistic):                        0.00
# Time:                        23:13:40   Log-Likelihood:                         -6144.2
# No. Observations:                 731   AIC:                                  1.229e+04
# Df Residuals:                     729   BIC:                                  1.230e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# atemp       7278.0376    108.914     66.824      0.000    7064.216    7491.859
# yr          2092.9967     77.196     27.113      0.000    1941.443    2244.550
# ==============================================================================
# Omnibus:                       44.574   Durbin-Watson:                   0.918
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               59.099
# Skew:                          -0.527   Prob(JB):                     1.47e-13
# Kurtosis:                       3.911   Cond. No.                         2.49
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#season True
variaveis = ['atemp', 'yr','season']
X = dados[variaveis]
Y = dados['cnt']
model = sm.OLS(Y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    cnt   R-squared (uncentered):                   0.957
# Model:                            OLS   Adj. R-squared (uncentered):              0.957
# Method:                 Least Squares   F-statistic:                              5460.
# Date:                Wed, 29 Mar 2023   Prob (F-statistic):                        0.00
# Time:                        23:13:40   Log-Likelihood:                         -6095.0
# No. Observations:                 731   AIC:                                  1.220e+04
# Df Residuals:                     728   BIC:                                  1.221e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# atemp       5663.2141    187.872     30.144      0.000    5294.378    6032.050
# yr          2025.4662     72.532     27.925      0.000    1883.070    2167.862
# season       338.9956     33.133     10.231      0.000     273.948     404.044
# ==============================================================================
# Omnibus:                      100.481   Durbin-Watson:                   1.034
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              213.108
# Skew:                          -0.783   Prob(JB):                     5.30e-47
# Kurtosis:                       5.132   Cond. No.                         14.3
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#weathersit true
variaveis = ['atemp', 'yr', 'season', 'weathersit']
X = dados[variaveis]
Y = dados['cnt']
model = sm.OLS(Y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    cnt   R-squared (uncentered):                   0.964
# Model:                            OLS   Adj. R-squared (uncentered):              0.964
# Method:                 Least Squares   F-statistic:                              4937.
# Date:                Wed, 29 Mar 2023   Prob (F-statistic):                        0.00
# Time:                        23:13:40   Log-Likelihood:                         -6028.9
# No. Observations:                 731   AIC:                                  1.207e+04
# Df Residuals:                     727   BIC:                                  1.208e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# atemp       6492.4740    185.112     35.073      0.000    6129.056    6855.892
# yr          2134.4646     66.924     31.894      0.000    2003.078    2265.851
# season       456.7422     31.837     14.346      0.000     394.239     519.245
# weathersit  -586.1127     48.817    -12.006      0.000    -681.952    -490.273
# ==============================================================================
# Omnibus:                      118.698   Durbin-Watson:                   0.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              270.584
# Skew:                          -0.883   Prob(JB):                     1.75e-59
# Kurtosis:                       5.402   Cond. No.                         17.0
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#mnth true
variaveis = ['atemp', 'yr', 'season', 'weathersit', 'mnth']
X = dados[variaveis]
Y = dados['cnt']
model = sm.OLS(Y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    cnt   R-squared (uncentered):                   0.965
# Model:                            OLS   Adj. R-squared (uncentered):              0.964
# Method:                 Least Squares   F-statistic:                              3970.
# Date:                Wed, 29 Mar 2023   Prob (F-statistic):                        0.00
# Time:                        23:13:40   Log-Likelihood:                         -6026.6
# No. Observations:                 731   AIC:                                  1.206e+04
# Df Residuals:                     726   BIC:                                  1.209e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# atemp       6452.2020    185.571     34.769      0.000    6087.882    6816.522
# yr          2136.7876     66.762     32.006      0.000    2005.718    2267.857
# season       560.6491     57.441      9.760      0.000     447.878     673.420
# weathersit  -577.6856     48.847    -11.826      0.000    -673.585    -481.787
# mnth         -38.9417     17.939     -2.171      0.030     -74.159      -3.724
# ==============================================================================
# Omnibus:                      118.920   Durbin-Watson:                   0.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              278.255
# Skew:                          -0.875   Prob(JB):                     3.78e-61
# Kurtosis:                       5.464   Cond. No.                         44.0
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#windspeed true
variaveis = ['atemp', 'yr', 'season', 'weathersit', 'mnth', 'windspeed']
X = dados[variaveis]
Y = dados['cnt']
model = sm.OLS(Y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    cnt   R-squared (uncentered):                   0.965
# Model:                            OLS   Adj. R-squared (uncentered):              0.964
# Method:                 Least Squares   F-statistic:                              3308.
# Date:                Wed, 29 Mar 2023   Prob (F-statistic):                        0.00
# Time:                        23:13:40   Log-Likelihood:                         -6026.1
# No. Observations:                 731   AIC:                                  1.206e+04
# Df Residuals:                     725   BIC:                                  1.209e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# atemp       6503.2423    193.725     33.569      0.000    6122.914    6883.571
# yr          2144.7794     67.333     31.853      0.000    2012.588    2276.971
# season       561.2469     57.451      9.769      0.000     448.456     674.037
# weathersit  -554.3825     55.043    -10.072      0.000    -662.445    -446.320
# mnth         -39.1650     17.942     -2.183      0.029     -74.390      -3.940
# windspeed   -340.3501    370.397     -0.919      0.358   -1067.528     386.828
# ==============================================================================
# Omnibus:                      121.340   Durbin-Watson:                   0.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              283.049
# Skew:                          -0.892   Prob(JB):                     3.44e-62
# Kurtosis:                       5.471   Cond. No.                         87.8
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#hum true
variaveis = ['atemp', 'yr', 'season', 'weathersit', 'mnth', 'hum']
X = dados[variaveis]
Y = dados['cnt']
model = sm.OLS(Y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    cnt   R-squared (uncentered):                   0.965
# Model:                            OLS   Adj. R-squared (uncentered):              0.964
# Method:                 Least Squares   F-statistic:                              3305.
# Date:                Wed, 29 Mar 2023   Prob (F-statistic):                        0.00
# Time:                        23:13:40   Log-Likelihood:                         -6026.5
# No. Observations:                 731   AIC:                                  1.206e+04
# Df Residuals:                     725   BIC:                                  1.209e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# atemp       6398.3793    216.598     29.540      0.000    5973.144    6823.614
# yr          2136.1800     66.809     31.974      0.000    2005.018    2267.342
# season       558.8284     57.595      9.703      0.000     445.755     671.902
# weathersit  -608.4587     80.348     -7.573      0.000    -766.202    -450.716
# mnth         -39.9110     18.060     -2.210      0.027     -75.367      -4.455
# hum          129.9018    269.211      0.483      0.630    -398.625     658.429
# ==============================================================================
# Omnibus:                      116.389   Durbin-Watson:                   1.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              269.838
# Skew:                          -0.861   Prob(JB):                     2.54e-59
# Kurtosis:                       5.428   Cond. No.                         72.1
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#holiday true
variaveis = ['atemp', 'yr', 'season', 'weathersit', 'mnth', 'holiday']
X = dados[variaveis]
Y = dados['cnt']
model = sm.OLS(Y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    cnt   R-squared (uncentered):                   0.965
# Model:                            OLS   Adj. R-squared (uncentered):              0.965
# Method:                 Least Squares   F-statistic:                              3347.
# Date:                Wed, 29 Mar 2023   Prob (F-statistic):                        0.00
# Time:                        23:13:40   Log-Likelihood:                         -6022.0
# No. Observations:                 731   AIC:                                  1.206e+04
# Df Residuals:                     725   BIC:                                  1.208e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# atemp       6462.4384    184.577     35.012      0.000    6100.070    6824.807
# yr          2141.9911     66.415     32.251      0.000    2011.601    2272.381
# season       555.6032     57.148      9.722      0.000     443.407     667.799
# weathersit  -575.6847     48.582    -11.850      0.000    -671.063    -480.306
# mnth         -36.1571     17.863     -2.024      0.043     -71.227      -1.087
# holiday     -613.0596    203.339     -3.015      0.003   -1012.263    -213.856
# ==============================================================================
# Omnibus:                      120.079   Durbin-Watson:                   1.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              286.586
# Skew:                          -0.876   Prob(JB):                     5.87e-63
# Kurtosis:                       5.518   Cond. No.                         47.7
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#weekday false
variaveis = ['atemp', 'yr', 'season', 'weathersit', 'mnth', 'holiday', 'weekday']
X = dados[variaveis]
Y = dados['cnt']
model = sm.OLS(Y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    cnt   R-squared (uncentered):                   0.967
# Model:                            OLS   Adj. R-squared (uncentered):              0.966
# Method:                 Least Squares   F-statistic:                              3001.
# Date:                Wed, 29 Mar 2023   Prob (F-statistic):                        0.00
# Time:                        23:13:41   Log-Likelihood:                         -6005.6
# No. Observations:                 731   AIC:                                  1.203e+04
# Df Residuals:                     724   BIC:                                  1.206e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# atemp       6239.5196    184.693     33.783      0.000    5876.921    6602.118
# yr          2116.6789     65.134     32.497      0.000    1988.806    2244.552
# season       550.8677     55.924      9.850      0.000     441.075     660.660
# weathersit  -654.8461     49.478    -13.235      0.000    -751.984    -557.708
# mnth         -39.7043     17.490     -2.270      0.023     -74.041      -5.368
# holiday     -528.8553    199.496     -2.651      0.008    -920.515    -137.195
# weekday       91.5747     15.880      5.767      0.000      60.399     122.751
# ==============================================================================
# Omnibus:                      121.165   Durbin-Watson:                   1.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              277.146
# Skew:                          -0.898   Prob(JB):                     6.58e-61
# Kurtosis:                       5.423   Cond. No.                         50.9
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#workingday false
variaveis = ['atemp', 'yr', 'season', 'weathersit', 'mnth', 'holiday', 'weekday', 'workingday']
X = dados[variaveis]
Y = dados['cnt']
model = sm.OLS(Y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    cnt   R-squared (uncentered):                   0.967
# Model:                            OLS   Adj. R-squared (uncentered):              0.967
# Method:                 Least Squares   F-statistic:                              2648.
# Date:                Wed, 29 Mar 2023   Prob (F-statistic):                        0.00
# Time:                        23:13:41   Log-Likelihood:                         -6002.2
# No. Observations:                 731   AIC:                                  1.202e+04
# Df Residuals:                     723   BIC:                                  1.206e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# atemp       6131.6633    188.622     32.508      0.000    5761.351    6501.976
# yr          2107.2804     64.980     32.430      0.000    1979.709    2234.852
# season       545.6338     55.741      9.789      0.000     436.199     655.068
# weathersit  -688.6526     50.983    -13.507      0.000    -788.745    -588.560
# mnth         -39.3615     17.422     -2.259      0.024     -73.564      -5.159
# holiday     -415.4056    203.483     -2.041      0.042    -814.894     -15.918
# weekday       87.7757     15.885      5.526      0.000      56.589     118.963
# workingday   185.0566     71.438      2.590      0.010      44.806     325.307
# ==============================================================================
# Omnibus:                      106.063   Durbin-Watson:                   1.015
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              245.140
# Skew:                          -0.792   Prob(JB):                     5.87e-54
# Kurtosis:                       5.354   Cond. No.                         53.2
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#Modelo final que melhor explica a correlação
variaveis = ['atemp', 'yr', 'season', 'weathersit', 'mnth', 'holiday', 'weekday' , 'workingday']
X = dados[variaveis]
Y = dados['cnt']
model = sm.OLS(Y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    cnt   R-squared (uncentered):                   0.967
# Model:                            OLS   Adj. R-squared (uncentered):              0.967
# Method:                 Least Squares   F-statistic:                              2648.
# Date:                Wed, 29 Mar 2023   Prob (F-statistic):                        0.00
# Time:                        23:13:41   Log-Likelihood:                         -6002.2
# No. Observations:                 731   AIC:                                  1.202e+04
# Df Residuals:                     723   BIC:                                  1.206e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# atemp       6131.6633    188.622     32.508      0.000    5761.351    6501.976
# yr          2107.2804     64.980     32.430      0.000    1979.709    2234.852
# season       545.6338     55.741      9.789      0.000     436.199     655.068
# weathersit  -688.6526     50.983    -13.507      0.000    -788.745    -588.560
# mnth         -39.3615     17.422     -2.259      0.024     -73.564      -5.159
# holiday     -415.4056    203.483     -2.041      0.042    -814.894     -15.918
# weekday       87.7757     15.885      5.526      0.000      56.589     118.963
# workingday   185.0566     71.438      2.590      0.010      44.806     325.307
# ==============================================================================
# Omnibus:                      106.063   Durbin-Watson:                   1.015
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              245.140
# Skew:                          -0.792   Prob(JB):                     5.87e-54
# Kurtosis:                       5.354   Cond. No.                         53.2
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## CNT = atemp + yr + season + weathersit + mnth + holiday + weekday + workingday

# %% [markdown]
# Foi removida a constante neste estudo separado, o que resultou em melhores resultados.
# Foram removidas as variáveis "instant", "dteday", "hr", "casual" e "registered" por não fazerem sentido dentro da análise.

# %% [markdown]
# As variáveis "temp", "windspeed" e "hum" por alterarem o P valor acima de 5%
